# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from utils import *

sns.set(style='whitegrid')
np.set_printoptions(suppress=True)

# %%
import importlib
import stocks
importlib.reload(stocks)
from stocks import Stocks

stocks = Stocks(['AAPL', 'GE', 'JPM', 'MSFT', 'GS', 'MMM', 'SPY'], start='2017-1-1', end='2018-03-09')

prices = stocks.prices
sr = simple_returns(prices)
lr = log_returns(prices)
prices.tail()
# Out:
#               AAPL     GE     JPM   MSFT      GS     MMM     SPY
# date
# 2018-02-09  152.07  13.90  104.19  85.18  239.48  210.33  251.86
# 2018-02-16  167.65  14.00  108.59  89.29  257.08  222.34  263.04
# 2018-02-23  170.63  13.60  111.08  91.29  256.26  222.67  264.58
# 2018-03-02  171.32  13.25  107.30  90.31  248.65  216.42  259.16
# 2018-03-09  174.99  14.02  111.77  93.70  260.84  226.74  268.59

# %%
import importlib
import visualizations
importlib.reload(visualizations)
from visualizations import *

show_sharpe_ratio(simple_returns(prices))
# Out:
# <style  type="text/css" >
#     #T_0a75a406_5d78_11ea_99d7_933964bafa58row0_col0 {
#             background-color:  #249424;
#             color:  #000000;
#         }    #T_0a75a406_5d78_11ea_99d7_933964bafa58row1_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_0a75a406_5d78_11ea_99d7_933964bafa58row2_col0 {
#             background-color:  #2f9a2f;
#             color:  #000000;
#         }    #T_0a75a406_5d78_11ea_99d7_933964bafa58row3_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_0a75a406_5d78_11ea_99d7_933964bafa58row4_col0 {
#             background-color:  #65b865;
#             color:  #000000;
#         }    #T_0a75a406_5d78_11ea_99d7_933964bafa58row5_col0 {
#             background-color:  #319b31;
#             color:  #000000;
#         }    #T_0a75a406_5d78_11ea_99d7_933964bafa58row6_col0 {
#             background-color:  #239323;
#             color:  #000000;
#         }</style><table id="T_0a75a406_5d78_11ea_99d7_933964bafa58" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Sharpe ratio</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0a75a406_5d78_11ea_99d7_933964bafa58level0_row0" class="row_heading level0 row0" >AAPL</th>
#                         <td id="T_0a75a406_5d78_11ea_99d7_933964bafa58row0_col0" class="data row0 col0" >2.10906</td>
#             </tr>
#             <tr>
#                         <th id="T_0a75a406_5d78_11ea_99d7_933964bafa58level0_row1" class="row_heading level0 row1" >GE</th>
#                         <td id="T_0a75a406_5d78_11ea_99d7_933964bafa58row1_col0" class="data row1 col0" >-2.2996</td>
#             </tr>
#             <tr>
#                         <th id="T_0a75a406_5d78_11ea_99d7_933964bafa58level0_row2" class="row_heading level0 row2" >JPM</th>
#                         <td id="T_0a75a406_5d78_11ea_99d7_933964bafa58row2_col0" class="data row2 col0" >1.85306</td>
#             </tr>
#             <tr>
#                         <th id="T_0a75a406_5d78_11ea_99d7_933964bafa58level0_row3" class="row_heading level0 row3" >MSFT</th>
#                         <td id="T_0a75a406_5d78_11ea_99d7_933964bafa58row3_col0" class="data row3 col0" >2.93414</td>
#             </tr>
#             <tr>
#                         <th id="T_0a75a406_5d78_11ea_99d7_933964bafa58level0_row4" class="row_heading level0 row4" >GS</th>
#                         <td id="T_0a75a406_5d78_11ea_99d7_933964bafa58row4_col0" class="data row4 col0" >0.633064</td>
#             </tr>
#             <tr>
#                         <th id="T_0a75a406_5d78_11ea_99d7_933964bafa58level0_row5" class="row_heading level0 row5" >MMM</th>
#                         <td id="T_0a75a406_5d78_11ea_99d7_933964bafa58row5_col0" class="data row5 col0" >1.81316</td>
#             </tr>
#             <tr>
#                         <th id="T_0a75a406_5d78_11ea_99d7_933964bafa58level0_row6" class="row_heading level0 row6" >SPY</th>
#                         <td id="T_0a75a406_5d78_11ea_99d7_933964bafa58row6_col0" class="data row6 col0" >2.12536</td>
#             </tr>
#     </tbody></table>

# %%
plot(prices)

# %%
plot_cumulative_returns(sr)

# %%
prices
# Out:
#               AAPL     GE     JPM   MSFT      GS     MMM     SPY
# date
# 2017-01-06  112.37  27.97   79.29  59.38  232.33  162.64  214.66
# 2017-01-13  113.45  27.74   79.83  59.25  231.76  161.87  214.51
# 2017-01-20  114.36  27.01   77.04  59.28  220.28  162.88  214.21
# 2017-10-06  149.84  22.37   91.29  73.05  235.59  201.20  243.74
# 2017-10-13  151.47  21.08   90.30  74.48  228.42  202.32  244.30
# 2017-10-20  150.76  21.86   93.73  75.75  234.35  205.66  246.37
# 2017-10-27  157.32  19.07   95.86  80.56  231.46  218.13  246.94
# 2017-11-03  166.44  18.47   95.52  80.87  234.04  215.79  247.65
# 2017-11-10  169.14  18.79   91.85  80.62  229.97  211.36  247.31
# 2017-11-17  164.76  16.70   92.44  79.60  227.93  213.13  247.09
# 2017-11-24  169.43  16.68   92.61  80.43  225.95  216.10  249.48
# 2017-12-01  165.63  16.40   98.71  81.40  239.14  225.22  253.41
# 2017-12-08  164.01  16.36   99.78  81.30  240.49  222.40  254.42
# 2017-12-15  168.46  16.46   99.98  83.90  247.04  222.28  256.68
# 2017-12-22  169.47  16.16  101.21  82.60  248.77  219.23  257.64
# 2017-12-29  163.87  16.23  100.73  82.63  244.73  219.82  257.02
# 2018-01-05  169.46  17.25  102.58  85.19  245.46  224.68  263.34
# 2018-01-12  171.48  17.45  106.68  86.56  246.91  228.32  267.67
# 2018-01-19  172.81  15.13  107.01  86.94  246.03  231.79  270.07
# 2018-01-26  166.08  15.01  110.14  90.86  257.58  241.55  276.01
# 2018-02-02  155.42  14.55  108.21  88.66  249.80  228.98  265.29
# 2018-02-09  152.07  13.90  104.19  85.18  239.48  210.33  251.86
# 2018-02-16  167.65  14.00  108.59  89.29  257.08  222.34  263.04
# 2018-02-23  170.63  13.60  111.08  91.29  256.26  222.67  264.58
# 2018-03-02  171.32  13.25  107.30  90.31  248.65  216.42  259.16
# 2018-03-09  174.99  14.02  111.77  93.70  260.84  226.74  268.59
#
# [62 rows x 7 columns]

# %%
plot_cumulative_returns(simple_returns(prices))

# %%
plot_drawdown(simple_returns(prices['GE']))

# %%
for ticker in stocks.prices.columns:
    plt.title('Stock price distribution')
    sns.distplot(stocks.prices[ticker])

# %%
import importlib
import utils
importlib.reload(utils)
from utils import *

cr     = cum_returns(sr)
sharpe = sharpe_ratio(sr)
dd     = drawdown(sr)
mdd    = max_drawdown(sr)

# %%
pd.DataFrame(sharpe, columns=['Sharpe ratio'])

# %%
sr.plot(title='Simple returns');
lr.plot(title='Log returns');

# %%
for ticker in sr.columns:
    plt.title('Simple returns distribution')
    sns.kdeplot(sr[ticker], shade=True)

# %%
for ticker in sr.columns:
    plt.title('Log returns distribution')
    sns.kdeplot(lr[ticker], shade=True)

# %%
for ticker in cr.columns:
    plt.title('Cumulative simple returns distribution')
    sns.kdeplot(cr[ticker], shade=True)
